# %% [markdown]
# ## **Model Representation**

# %% [markdown]
# ### **Notation:**

# %% [markdown]
# #### ```m``` = Number of training examples.
# #### ```x's``` = "input" variable/features
# #### ```y's``` = "output" variable/target

# %%
import pandas as pd

data = pd.DataFrame(data=[[2104, 460], [1416, 232], [1538, 315], [852, 178]], columns=['size in feet**2(x)', 'price ($) in 1000\'s(y)'])
display(data)
# Out:
#    size in feet**2(x)  price ($) in 1000's(y)
# 0                2104                     460
# 1                1416                     232
# 2                1538                     315
# 3                 852                     178

# %% [markdown]
# ### **Here:**
# #### ```(x, y)``` = one training example.
# #### ```(x**i, y**i)``` = i**th training example.
#
# #### This notation ```x(i)``` comma gives me ```y(i)``` And, we're going to use this to refer to the **ith** training example. So this superscript **i** over here, this is not exponentiation. This (x(i), y(i)), the superscript i in parentheses that's just an index into my training set and refers to the **ith** row in this table.
# #### So for example, ```x(1)``` refers to the input value for the first training example so that's **2104**. That's this x in the first row. x(2) will be equal to 1416. That's the second x and y(1) will be equal to 460.

# %% [markdown]
# ### **Convention**

# %% [markdown]
# #### Conventionally machine learning algorithm returns **function** which by convention is usually denoted lowercase ```h```.It takes a input ```x``` and output's ```y```. So ```h``` is a function that maps from ```x's``` to ```y's```.

# %% [markdown]
# #### We will also use ```X``` to denote the **space of input values**, and ```Y``` to denote the **space of output values**. In this example, ```X = Y = ℝ```.

# %% [markdown]
# ![a](img/a.png)

# %% [markdown]
# #### To describe the supervised learning problem slightly more formally, our goal is, given a training set, to learn a function ```h : X → Y``` so that **h(x) is a “good” predictor for the corresponding value of y.**

# %% [markdown]
# ![b](img/c.png)

# %% [markdown]
# >#### When the target variable that we’re trying to predict is continuous, such as in our housing example, we call the learning problem a *regression problem*. When **y** can take on only a small number of discrete values (such as if, given the living area, we wanted to predict if a dwelling is a house or an apartment, say), we call it a *classification problem*.

# %% [markdown]
# >## **Cost Function**
# #### We can measure the accuracy of our hypothesis function by using a cost function.

# %% [markdown]
# #### ```Hypothesis: h*sub*theta (x) = theta 0 + theta 1 * x```  ![h](img/h.png)

# %% [markdown]
# #### These theta zero and theta one, they stabilize the parameters of the model.

# %% [markdown]
# >### How do we chose **theta values** ?

# %% [markdown]
# #### The idea is we get to choose our parameters **theta 0, theta 1** so that **h of x**, meaning the value we predict on input x, that this is at **least close to the values y**.

# %% [markdown]
# ![e](img/e.png)

# %% [markdown]
# >![g](img/g.png)

# %% [markdown]
# #### Here the (y hat - y)**2 can be written as SSR(Sum of the Squire Residual)<- Observed Unit - (Predicted Unit <- intercept + mx)

# %% [markdown]
# ## **Resource for this concept:**
# #### 1. [Linear Equation on Youtube](https://www.youtube.com/watch?v=Ft2_QtXAnh8)
# #### 2. [Gradient Descent](https://www.youtube.com/watch?v=sDv4f4s2SB8&t=553s)

# %% [markdown]
# ### **To break it apart**
# #### It is 1/2 of mean(x), where mean(x) is the mean of the squares of ![h](img/h.png) or the difference between the predicted value and the actual value.
# #### This function is otherwise called the "Squared error function", or "Mean squared error". The mean is halved 1/2 as a convenience for the computation of the gradient descent, as the derivative term of the square function will cancel out the 1/2 term. The following image summarizes what the cost function does:

# %% [markdown]
# >![i](img/i.png)

# %% [markdown]
# >## **Gradient Descent**

# %% [markdown]
# #### In mathematics, gradient descent is a first-order iterative optimization algorithm for finding a local minimum of a differentiable function.
# #### **Gradient Descent is an optimization algorithm used for minimizing the cost function in various machine learning algorithms.**
# >#### It is basically used for updating the parameters of the learning model.

# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x, y: np.sin(x) * np.cos(y)
x = np.linspace(-2, 2, 40)
y = np.linspace(-2, 2, 40)

X, Y = np.meshgrid(x, y)

F = f(X, Y)

plt.contour(X, Y, F, 15)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

fig = plt.figure(figsize=(12, 8))
# ax = fig.add_subplot(111, projection='3d')
ax = plt.axes(projection='3d')


# ax.contour3D(X, Y, F)
ax.plot_surface(X, Y, F, cmap=cm.coolwarm)
plt.show()

# %%
def plotter(E, A):
    fig = plt.figure(figsize=(12, 8))
    # ax = fig.add_subplot(111, projection='3d')
    ax = plt.axes(projection='3d')


    # ax.contour3D(X, Y, F)
    ax.plot_surface(X, Y, F, cmap=cm.Blues)
    ax.view_init(elev=E, azim=A)
    plt.show()

from ipywidgets import interactive
iplot= interactive(plotter, E=(-90, 90, 5), A=(-90,90, 5))
iplot
# Out:
# interactive(children=(IntSlider(value=0, description='E', max=90, min=-90, step=5), IntSlider(value=0, descrip…

# %% [markdown]
# >## **Stochastic Gradient Descent**
