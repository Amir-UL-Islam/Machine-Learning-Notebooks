# %% [markdown]
# <a href="https://www.kaggle.com/code/leoth9/get-started-sentiment-analysis-with-transformers?scriptVersionId=112631328" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h3><b>What is Sentiment Analysis?</b></h3>
# </div>
# <div class="alert alert-block alert-success">
# <h4>The process of computationally identifying and categorizing opinions expressed in a piece of text, especially in order <b>to determine whether the writer's attitude towards a particular topic, product, etc. is positive, negative, or neutral.</b></h4>
# </div>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import torch

# For show all columns and full value of columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth',300)

# Colors
color_pal = sns.color_palette()
plt.style.use('ggplot')

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/nlp-getting-started/sample_submission.csv
# /kaggle/input/nlp-getting-started/train.csv
# /kaggle/input/nlp-getting-started/test.csv
# /kaggle/input/crypto-tweets/crypto_10k_tweets_(2021_2022Nov).csv

# %%
df = pd.read_csv('/kaggle/input/crypto-tweets/crypto_10k_tweets_(2021_2022Nov).csv', lineterminator='\n').drop('Unnamed: 0', axis=1)
df.head()
# Out:
#                         Date         Username  \
# 0  2022-11-30 11:53:21+00:00   0xEthereumYoda
# 1  2022-11-30 11:53:21+00:00  Lawrenc32984128
# 2  2022-11-30 11:53:21+00:00  NITESHP55784410
# 3  2022-11-30 11:53:20+00:00          817coin
# 4  2022-11-30 11:53:18+00:00        slamtoken
#
#                                                                                                                                                                                                                                                                                                        Content  \
# 0                                                                                                                                                           #Ethereum price update: \n\n#ETH $1269.23 USD\n#Bitcoin 0.07510228 #BTC\n\nFollow for recent ETH price updates\n#altcoin, #cryptocurrency, #crypto
# 1  @mtmalinen @ecb Do well to understand that every dip in the price of #BTC provides a golden opportunity to accumulate \n\nOnes you understand this, you‘ll know to do: Buy,HODL,Be patient.\n\nfollow @btcskyy,she’s always available during ups and down,her tweets,TA,predictions &amp; tips are so ac...
# 2                                                                                                                                                                                                                              Kayla #Ethereum Harold #世界杯 Egbert #百家乐 Laverna #世界杯买球  https://t.co/smw7VJl9WK
# 3                                                                                                                                                                                                                                                     #Bitcoin https://t.co/2koLlCvCri https://t.co/MTR3woxLb9
# 4                                                                                 Yesterday we made a 3,000 SLAM buyback and locked it forever in addition to the 100,000 SLAM we’ve locked in the last 7 months! 🔥\n\nSee you at another burning fest 🎉\n\n\n#slamtoken | #bnb | #bsc https://t.co/sTkBvYxHyz
#
#                                                               URL  \
# 0   https://twitter.com/0xEthereumYoda/status/1597921724422848513
# 1  https://twitter.com/Lawrenc32984128/status/1597921722954821638
# 2  https://twitter.com/NITESHP55784410/status/1597921722111389697
# 3          https://twitter.com/817coin/status/1597921717422534656
# 4        https://twitter.com/slamtoken/status/1597921712313896961
#
#                                                                        Hashtags
# 0  ['Ethereum', 'ETH', 'Bitcoin', 'BTC', 'altcoin', 'cryptocurrency', 'crypto']
# 1                                                                       ['BTC']
# 2                                           ['Ethereum', '世界杯', '百家乐', '世界杯买球']
# 3                                                                   ['Bitcoin']
# 4                                                   ['slamtoken', 'bnb', 'bsc']

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h3>Basic Stuffs(Level 01)</h3>
# </div>

# %%
string = 'Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all'
strings = [''.join(i) for i in df['Content'][:10]]

# %%
# Libries for Sentiment Analysis
from transformers import pipeline

# %% [markdown]
# #### For Details about ```pipeline``` [huggingface](https://huggingface.co/docs/transformers/main_classes/pipelines)

# %%
# Creating an Instance
classifier = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# 2022-12-01 08:01:52.339581: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.340638: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.341854: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.342716: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.343561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.344356: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.349368: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-01 08:01:52.609864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.610816: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.611667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.612497: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.613333: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:01:52.614163: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:02:02.877345: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:02:02.878298: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:02:02.879258: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:02:02.880173: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:02:02.880895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:02:02.881665: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13351 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-12-01 08:02:02.886681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-01 08:02:02.887610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13351 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %% [markdown]
# ### Sentiment Analysis for Single Statement

# %%
result = classifier(string)
result
# Out:
# [{'label': 'NEGATIVE', 'score': 0.726392924785614}]

# %% [markdown]
# ### Sentiment Analysis for list of Statement

# %%
result = classifier(strings)
result
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9906522035598755},
#  {'label': 'POSITIVE', 'score': 0.9995393753051758},
#  {'label': 'NEGATIVE', 'score': 0.990452766418457},
#  {'label': 'NEGATIVE', 'score': 0.9965961575508118},
#  {'label': 'POSITIVE', 'score': 0.993540346622467},
#  {'label': 'NEGATIVE', 'score': 0.9901347756385803},
#  {'label': 'NEGATIVE', 'score': 0.999015212059021},
#  {'label': 'NEGATIVE', 'score': 0.9863199591636658},
#  {'label': 'NEGATIVE', 'score': 0.9989056587219238},
#  {'label': 'NEGATIVE', 'score': 0.9944586753845215}]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h3>Level 02</h3>
# </div>

# %%
# Libries for Sentiment Analysis
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax

# %%
regex_tokenized = []
final_tokenized_strings = []

# Tokenizer
for words in strings:
    for word in words.split(' '):
        word = '@user' if word.startswith('@') and len(word) > 1 else word
        word = 'http' if word.startswith('http') else word
        word = 'hastag' if word.startswith('#') else word
        regex_tokenized.append(word)
    string = ''.join(regex_tokenized)
    final_tokenized_strings.append(string)
final_tokenized_strings[1]
# Out:
# 'hastagpriceupdate:\n\n#ETH$1269.23USD\n#Bitcoin0.07510228hastagforrecentETHpriceupdates\n#altcoin,hastaghastag@user@userDowelltounderstandthateverydipinthepriceofhastagprovidesagoldenopportunitytoaccumulate\n\nOnesyouunderstandthis,you‘llknowtodo:Buy,HODL,Bepatient.\n\nfollow@useralwaysavailableduringupsanddown,hertweets,TA,predictions&amp;tipsaresoaccurate'

# %% [markdown]
# #### I am going use [Twitter-roBERTa-base for Sentiment Analysis](https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment). You can use any models from [Here](https://huggingface.co/models).

# %%
# Model Name
roberta = "cardiffnlp/twitter-roberta-base-sentiment"

#
model = AutoModelForSequenceClassification.from_pretrained(roberta)

#
tokenizer = AutoTokenizer.from_pretrained(roberta)
# Out:
# Downloading:   0%|          | 0.00/747 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/476M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
tokenizer.model_max_length
# Out:
# 1000000000000000019884624838656

# %%
# labels
labels = ['Negative', 'Neutral', 'Positive']

# %% [markdown]
# ### Sentimental Analysis

# %%
# Encoding Tweets
encoded_tweets = []
outputs = []

# 
for tweets in final_tokenized_strings:
    encoded_tweets.append(tokenizer(tweets, return_tensors='pt'))

# Collecting Outputs
for index in range(len(encoded_tweets)):
    outputs.append(model(**encoded_tweets[index]))

# %% [markdown]
# ### Scores

# %%
scores = []
for o in outputs:
    scores.append(softmax(o[0][0].detach().numpy()))

len(scores)
for i in range(len(scores)):
    for j in range(len(scores[i])):
        l = labels[j]
        s = scores[i][j]
        print(l, s)
    print('\n')
# Out:
# Negative 0.040085576
# Neutral 0.89186263
# Positive 0.06805183
#
#
# Negative 0.04013138
# Neutral 0.794213
# Positive 0.16565554
#
#
# Negative 0.05258155
# Neutral 0.82626903
# Positive 0.12114936
#
#
# Negative 0.054418694
# Neutral 0.82641554
# Positive 0.11916577
#
#
# Negative 0.07666535
# Neutral 0.8041386
# Positive 0.119196095
#
#
# Negative 0.08093086
# Neutral 0.80641085
# Positive 0.11265837
#
#
# Negative 0.12416384
# Neutral 0.7642198
# Positive 0.11161643
#
#
# Negative 0.12958789
# Neutral 0.76208335
# Positive 0.10832865
#
#
# Negative 0.12986241
# Neutral 0.76544446
# Positive 0.104693055
#
#
# Negative 0.13723508
# Neutral 0.7388354
# Positive 0.123929635

# %% [markdown]
# ### Thank You
